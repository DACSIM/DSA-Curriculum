# %% [markdown]
# # DSA - Deep Learning [5] - Reinforcement learning

# %%
# Install necessary libraries
# !pip install flappy-bird-gymnasium pygame
# !apt-get install -y xvfb python3-opengl ffmpeg
# !pip install pyvirtualdisplay
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# Out:
# Collecting flappy-bird-gymnasium
#   Downloading flappy_bird_gymnasium-0.4.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (2.6.1)
# Collecting gymnasium (from flappy-bird-gymnasium)
#   Downloading gymnasium-1.0.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from flappy-bird-gymnasium) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from flappy-bird-gymnasium) (3.8.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium->flappy-bird-gymnasium) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium->flappy-bird-gymnasium) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium->flappy-bird-gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flappy-bird-gymnasium) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flappy-bird-gymnasium) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flappy-bird-gymnasium) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flappy-bird-gymnasium) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flappy-bird-gymnasium) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flappy-bird-gymnasium) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flappy-bird-gymnasium) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flappy-bird-gymnasium) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->flappy-bird-gymnasium) (1.16.0)
# Downloading flappy_bird_gymnasium-0.4.0-py3-none-any.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 18.0 MB/s eta 0:00:00
# Downloading gymnasium-1.0.0-py3-none-any.whl (958 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 25.6 MB/s eta 0:00:00
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium, flappy-bird-gymnasium
# Successfully installed farama-notifications-0.0.4 flappy-bird-gymnasium-0.4.0 gymnasium-1.0.0
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   freeglut3 libfontenc1 libglu1-mesa libxfont2 libxkbfile1 x11-xkb-utils xfonts-base
#   xfonts-encodings xfonts-utils xserver-common
# Suggested packages:
#   libgle3 python3-numpy
# The following NEW packages will be installed:
#   freeglut3 libfontenc1 libglu1-mesa libxfont2 libxkbfile1 python3-opengl x11-xkb-utils xfonts-base
#   xfonts-encodings xfonts-utils xserver-common xvfb
# 0 upgraded, 12 newly installed, 0 to remove and 49 not upgraded.
# Need to get 8,639 kB of archives.
# After this operation, 20.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 freeglut3 amd64 2.8.1-6 [74.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa amd64 9.0.2-1 [145 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-opengl all 3.1.5+dfsg-1 [605 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.12 [28.7 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.12 [864 kB]
# Fetched 8,639 kB in 2s (4,614 kB/s)
# Selecting previously unselected package freeglut3:amd64.
# (Reading database ... 123629 files and directories currently installed.)
# Preparing to unpack .../00-freeglut3_2.8.1-6_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-6) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../01-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../02-libxfont2_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.5-1build1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../03-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package libglu1-mesa:amd64.
# Preparing to unpack .../04-libglu1-mesa_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa:amd64 (9.0.2-1) ...
# Selecting previously unselected package python3-opengl.
# Preparing to unpack .../05-python3-opengl_3.1.5+dfsg-1_all.deb ...
# Unpacking python3-opengl (3.1.5+dfsg-1) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../06-x11-xkb-utils_7.7+5build4_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5build4) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../07-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../08-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../09-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../10-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.12_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../11-xvfb_2%3a21.1.4-2ubuntu1.7~22.04.12_amd64.deb ...
# Unpacking xvfb (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up freeglut3:amd64 (2.8.1-6) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up libglu1-mesa:amd64 (9.0.2-1) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up python3-opengl (3.1.5+dfsg-1) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)

# %%
# Import necessary libraries
import os
import torch
import random
import numpy as np
import pygame
import imageio
from IPython.display import display, Image
from PIL import Image as PILImage  # Importing PIL for image manipulation
from flappy_bird_gymnasium.envs.flappy_bird_env import FlappyBirdEnv

# Set environment variables for rendering and audio in Colab
os.environ["SDL_VIDEODRIVER"] = "dummy"
os.environ["SDL_AUDIODRIVER"] = "dummy"
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
class CustomFlappyBirdEnv(FlappyBirdEnv):
    def __init__(self):
        super().__init__()

        # Initialize pygame and enforce dummy display
        pygame.init()
        if not pygame.display.get_init():
            pygame.display.init()
        pygame.display.set_mode((1, 1))  # Enforce dummy video mode

        # Initialize pygame mixer for audio
        if not pygame.mixer.get_init():
            pygame.mixer.init()

        # Initialize game surface
        self._surface = pygame.Surface((288, 512))  # Game surface dimensions

        # Initialize display surface (required for FlappyBirdEnv rendering)
        self._display = pygame.display.set_mode((288, 512))  # Create display window of appropriate size

        # Initialize the FPS clock for controlling the frame rate
        self._fps_clock = pygame.time.Clock()  # Initialize the FPS clock

        # Initialize image assets
        self._images = {}

        # Load images required for the game
        self._images["background"] = self._load_image("background-day.png")
        self._images["pipe"] = [
            self._load_image("pipe-green.png"),  # Top pipe
            pygame.transform.flip(self._load_image("pipe-green.png"), False, True)  # Bottom pipe (flipped)
        ]
        self._images["base"] = self._load_image("base.png")
        self._images["player"] = [
            self._load_image("yellowbird-upflap.png"),
            self._load_image("yellowbird-midflap.png"),
            self._load_image("yellowbird-downflap.png"),
        ]
        self._images["numbers"] = {
            i: self._load_image(f"{i}.png") for i in range(10)  # Load images for digits 0-9
        }

        # Load audio assets if needed
        self._audio = {
            "wing": self._load_audio("wing.wav"),
            "point": self._load_audio("point.wav"),
            "hit": self._load_audio("hit.wav"),
            "die": self._load_audio("die.wav"),
        }

        # Additional attributes required by the parent class
        self._score = 0
        self._player_index = 0
        self._base_shift = self._images["base"].get_width() - self._surface.get_width()
        self._pipes = []
        self._player_y = 256
        self._player_velocity_y = 0
        self._gravity = 1
        self._pipe_gap = 100

    def _load_image(self, filename):
        """
        Load an image from the assets directory.
        Args:
            filename: Name of the image file.
        Returns:
            Loaded pygame image.
        """
        assets_path = "/usr/local/lib/python3.10/dist-packages/flappy_bird_gymnasium/assets/sprites"
        filepath = os.path.join(assets_path, filename)
        return pygame.image.load(filepath).convert_alpha()

    def _load_audio(self, filename):
        """
        Load an audio file from the assets directory.
        Args:
            filename: Name of the audio file.
        Returns:
            Loaded pygame audio sound.
        """
        assets_path = "/usr/local/lib/python3.10/dist-packages/flappy_bird_gymnasium/assets/audio"
        filepath = os.path.join(assets_path, filename)
        return pygame.mixer.Sound(filepath)

    def render(self):
        """
        Render the game screen to the display and capture the frame for Colab visualization.
        """
        super().render()  # Call the parent class's render method

        # Capture the screen as an array
        frame = pygame.surfarray.array3d(pygame.display.get_surface())
        self.frames.append(frame)  # Save the frame for GIF creation

        # Control frame rate
        self._fps_clock.tick(self.metadata["render_fps"])

    def create_gif(self, gif_name="flappy_bird_game.gif"):
        """
        Create and display a GIF from the captured frames.
        """
        flipped_frames = []
        for frame in self.frames:
            pil_frame = PILImage.fromarray(frame)
            flipped_frame = pil_frame.rotate(270, expand=True)  # Rotate 270 degrees
            flipped_frames.append(flipped_frame)

        # Save and display the GIF
        flipped_gif_name = gif_name.replace(".gif", "_flipped.gif")
        imageio.mimsave(flipped_gif_name, flipped_frames, duration=1 / self.metadata["render_fps"])
        display(Image(flipped_gif_name))

    def reset(self):
        """
        Reset the environment and clear the stored frames.
        """
        self.frames = []  # Clear captured frames
        return super().reset()

# %%
class DQN(torch.nn.Module):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.fc1 = torch.nn.Linear(state_size, 128)
        self.fc2 = torch.nn.Linear(128, 128)
        self.fc3 = torch.nn.Linear(128, action_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# %%
def preprocess_state(state):
    """
    Preprocess the state for the DQN model.
    Args:
        state: The raw state from the environment, which could be a tuple or array.
    Returns:
        A flattened and normalized 1D array representing the observation.
    """
    if isinstance(state, tuple):
        # If state is a tuple, take the first element (assuming it’s the observation)
        observation = state[0]
    else:
        observation = state

    # Ensure the observation is a NumPy array
    observation = np.array(observation, dtype=np.float32)

    # Normalize pixel values if it's an image or large array
    if observation.max() > 1.0:
        observation = observation / 255.0  # Normalize to range [0, 1]

    return observation.flatten()  # Flatten to a 1D array

# %%
def train_dqn(env, num_episodes, model_save_path="flappy_bird_dqn_final.pth", checkpoint_interval=100):
    """
    Train the DQN model on the environment.
    Args:
        env: The Flappy Bird environment.
        num_episodes: Number of training episodes.
        model_save_path: File path to save the final trained model.
        checkpoint_interval: Number of episodes between saving model checkpoints.
    Returns:
        Trained model.
    """
    # Determine state and action sizes dynamically
    state = preprocess_state(env.reset())
    state_size = state.shape[0]
    action_size = env.action_space.n

    # Initialize the DQN model
    model = DQN(state_size, action_size)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    loss_fn = torch.nn.MSELoss()

    # Replay buffer for storing experiences
    replay_buffer = []
    max_buffer_size = 1000

    # Hyperparameters
    gamma = 0.99  # Discount factor
    epsilon = 1.0  # Initial exploration rate
    epsilon_min = 0.01  # Minimum exploration rate
    epsilon_decay = 0.995  # Decay factor for exploration rate

    # Metrics
    rewards_per_episode = []  # Track rewards per episode
    steps_per_episode = []  # Track steps per episode

    for episode in range(num_episodes):
        state = preprocess_state(env.reset())  # Preprocess the initial state
        done = False
        total_reward = 0
        steps = 0

        while not done:
            # Convert state to tensor
            state_tensor = torch.FloatTensor(state).unsqueeze(0)

            # Select an action (epsilon-greedy policy)
            if random.random() < epsilon:  # Explore
                action = random.choice(range(action_size))
            else:  # Exploit the learned policy
                with torch.no_grad():
                    action = torch.argmax(model(state_tensor)).item()

            # Perform the action in the environment
            next_state, reward, done, _, _ = env.step(action)
            next_state = preprocess_state(next_state)  # Preprocess the next state
            total_reward += reward
            steps += 1

            # Store the experience in the replay buffer
            replay_buffer.append((state, action, reward, next_state, done))
            if len(replay_buffer) > max_buffer_size:
                replay_buffer.pop(0)  # Remove the oldest experience

            # Sample a random batch from the replay buffer for training
            if len(replay_buffer) >= 32:
                batch = random.sample(replay_buffer, 32)
                states, actions, rewards, next_states, dones = zip(*batch)

                # Convert batch to tensors
                states_tensor = torch.FloatTensor(states)
                actions_tensor = torch.LongTensor(actions).unsqueeze(1)
                rewards_tensor = torch.FloatTensor(rewards).unsqueeze(1)
                next_states_tensor = torch.FloatTensor(next_states)
                dones_tensor = torch.FloatTensor(dones).unsqueeze(1)

                # Compute Q values for the current states
                q_values = model(states_tensor).gather(1, actions_tensor)

                # Compute target Q values
                with torch.no_grad():
                    next_q_values = model(next_states_tensor).max(1, keepdim=True)[0]
                    targets = rewards_tensor + gamma * next_q_values * (1 - dones_tensor)

                # Compute loss
                loss = loss_fn(q_values, targets)

                # Backpropagation
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            # Move to the next state
            state = next_state

        # Decay exploration rate
        if epsilon > epsilon_min:
            epsilon *= epsilon_decay

        # Track metrics
        rewards_per_episode.append(total_reward)
        steps_per_episode.append(steps)

        # Print metrics for the current episode
        print(
            f"Episode {episode + 1}/{num_episodes}: "
            f"Total Reward = {total_reward:.2f}, "
            f"Steps = {steps}, "
            f"Epsilon = {epsilon:.4f}"
        )

        # Save model checkpoint every `checkpoint_interval` episodes
        if (episode + 1) % checkpoint_interval == 0:
            checkpoint_path = model_save_path.replace(".pth", f"_ep{episode + 1}.pth")
            torch.save(model.state_dict(), checkpoint_path)
            print(f"Checkpoint saved at episode {episode + 1}: {checkpoint_path}")

    # Save the final trained model
    torch.save(model.state_dict(), model_save_path)
    print(f"Final model saved to {model_save_path}")

    # Print overall metrics
    print(f"Training completed. Average Reward: {np.mean(rewards_per_episode):.2f}, Average Steps: {np.mean(steps_per_episode):.2f}")

    return model, rewards_per_episode, steps_per_episode

# %%
def load_model(env, model_path="flappy_bird_dqn_final.pth"):
    """
    Load the trained RL model.
    Args:
        env: The Flappy Bird environment.
        model_path: Path to the saved model file.
    Returns:
        Loaded model.
    """
    # Preprocess the initial state to determine its size
    state = preprocess_state(env.reset())
    state_size = state.shape[0]
    action_size = env.action_space.n

    # Initialize the DQN model with the correct dimensions
    model = DQN(state_size, action_size)
    model.load_state_dict(torch.load(model_path))
    model.eval()  # Set the model to evaluation mode
    return model

# %%
def test_rl_agent_playing(env, model, step_limit=500):
    """
    Test the RL agent playing the game and generate a flipped GIF of the gameplay.
    Args:
        env: The Flappy Bird environment instance.
        model: The trained RL model.
        step_limit: Maximum number of steps to run the environment.
    """
    state = preprocess_state(env.reset())  # Preprocess the initial state
    for step in range(step_limit):
        # Debugging: Print state shape
        print(f"Step {step}: State shape: {state.shape}, State type: {type(state)}")

        # Convert state to tensor
        state_tensor = torch.FloatTensor(state).unsqueeze(0)

        # Select action based on the trained model
        with torch.no_grad():
            action = torch.argmax(model(state_tensor)).item()

        # Take the action in the environment
        next_state, reward, done, _, _ = env.step(action)
        next_state = preprocess_state(next_state)  # Preprocess the next state
        print(f"Step {step + 1}: Reward: {reward}, Done: {done}")

        # Render the frame for visualization
        env.render()

        if done:
            break

        # Update state for the next step
        state = next_state

    # Create and display the GIF after the game is over
    env.create_gif("flappy_bird_rl_agent.gif")

# %%
# Initialize the environment
env = CustomFlappyBirdEnv()

# %%
# Train the model
model = train_dqn(env, num_episodes=5000, model_save_path="flappy_bird_dqn_final.pth", checkpoint_interval=1000)
# Out:
# <ipython-input-7-783f1949abdc>:70: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   states_tensor = torch.FloatTensor(states)
# Streaming output truncated to the last 5000 lines.
# Episode 8/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.9607
# Episode 9/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.9559
# Episode 10/5000: Total Reward = -5.10, Steps = 50, Epsilon = 0.9511
# Episode 11/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.9464
# Episode 12/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.9416
# Episode 13/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.9369
# Episode 14/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.9322
# Episode 15/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.9276
# Episode 16/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.9229
# Episode 17/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.9183
# Episode 18/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.9137
# Episode 19/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.9092
# Episode 20/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.9046
# Episode 21/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.9001
# Episode 22/5000: Total Reward = -8.70, Steps = 50, Epsilon = 0.8956
# Episode 23/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.8911
# Episode 24/5000: Total Reward = -8.70, Steps = 50, Epsilon = 0.8867
# Episode 25/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.8822
# Episode 26/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.8778
# Episode 27/5000: Total Reward = -8.70, Steps = 50, Epsilon = 0.8734
# Episode 28/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.8691
# Episode 29/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.8647
# Episode 30/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.8604
# Episode 31/5000: Total Reward = -5.10, Steps = 50, Epsilon = 0.8561
# Episode 32/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.8518
# Episode 33/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.8475
# Episode 34/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.8433
# Episode 35/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.8391
# Episode 36/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.8349
# Episode 37/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.8307
# Episode 38/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.8266
# Episode 39/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.8224
# Episode 40/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.8183
# Episode 41/5000: Total Reward = -3.90, Steps = 50, Epsilon = 0.8142
# Episode 42/5000: Total Reward = -4.50, Steps = 50, Epsilon = 0.8102
# Episode 43/5000: Total Reward = -5.10, Steps = 50, Epsilon = 0.8061
# Episode 44/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.8021
# Episode 45/5000: Total Reward = -5.70, Steps = 50, Epsilon = 0.7981
# Episode 46/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.7941
# Episode 47/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.7901
# Episode 48/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.7862
# Episode 49/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.7822
# Episode 50/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.7783
# Episode 51/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.7744
# Episode 52/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.7705
# Episode 53/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.7667
# Episode 54/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.7629
# Episode 55/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.7590
# Episode 56/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.7553
# Episode 57/5000: Total Reward = -5.10, Steps = 50, Epsilon = 0.7515
# Episode 58/5000: Total Reward = -8.70, Steps = 50, Epsilon = 0.7477
# Episode 59/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.7440
# Episode 60/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.7403
# Episode 61/5000: Total Reward = -8.70, Steps = 50, Epsilon = 0.7366
# Episode 62/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.7329
# Episode 63/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.7292
# Episode 64/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.7256
# Episode 65/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.7219
# Episode 66/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.7183
# Episode 67/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.7147
# Episode 68/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.7112
# Episode 69/5000: Total Reward = -8.70, Steps = 50, Epsilon = 0.7076
# Episode 70/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.7041
# Episode 71/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.7005
# Episode 72/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.6970
# Episode 73/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.6936
# Episode 74/5000: Total Reward = -8.70, Steps = 50, Epsilon = 0.6901
# Episode 75/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.6866
# Episode 76/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.6832
# Episode 77/5000: Total Reward = -8.70, Steps = 50, Epsilon = 0.6798
# Episode 78/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.6764
# Episode 79/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.6730
# Episode 80/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.6696
# Episode 81/5000: Total Reward = -8.70, Steps = 50, Epsilon = 0.6663
# Episode 82/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.6630
# Episode 83/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.6597
# Episode 84/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.6564
# Episode 85/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.6531
# Episode 86/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.6498
# Episode 87/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.6466
# Episode 88/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.6433
# Episode 89/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.6401
# Episode 90/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.6369
# Episode 91/5000: Total Reward = -5.70, Steps = 50, Epsilon = 0.6337
# Episode 92/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.6306
# Episode 93/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.6274
# Episode 94/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.6243
# Episode 95/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.6211
# Episode 96/5000: Total Reward = -4.50, Steps = 50, Epsilon = 0.6180
# Episode 97/5000: Total Reward = -4.50, Steps = 50, Epsilon = 0.6149
# Episode 98/5000: Total Reward = -8.70, Steps = 50, Epsilon = 0.6119
# Episode 99/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.6088
# Episode 100/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.6058
# Episode 101/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.6027
# Episode 102/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.5997
# Episode 103/5000: Total Reward = -3.90, Steps = 50, Epsilon = 0.5967
# Episode 104/5000: Total Reward = -2.70, Steps = 50, Epsilon = 0.5937
# Episode 105/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.5908
# Episode 106/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.5878
# Episode 107/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.5849
# Episode 108/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.5820
# Episode 109/5000: Total Reward = -3.90, Steps = 50, Epsilon = 0.5790
# Episode 110/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.5762
# Episode 111/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.5733
# Episode 112/5000: Total Reward = -4.50, Steps = 50, Epsilon = 0.5704
# Episode 113/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.5676
# Episode 114/5000: Total Reward = -3.90, Steps = 50, Epsilon = 0.5647
# Episode 115/5000: Total Reward = -5.70, Steps = 50, Epsilon = 0.5619
# Episode 116/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.5591
# Episode 117/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.5563
# Episode 118/5000: Total Reward = -5.10, Steps = 50, Epsilon = 0.5535
# Episode 119/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.5507
# Episode 120/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.5480
# Episode 121/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.5452
# Episode 122/5000: Total Reward = -5.70, Steps = 50, Epsilon = 0.5425
# Episode 123/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.5398
# Episode 124/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.5371
# Episode 125/5000: Total Reward = -4.50, Steps = 50, Epsilon = 0.5344
# Episode 126/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.5318
# Episode 127/5000: Total Reward = -3.90, Steps = 50, Epsilon = 0.5291
# Episode 128/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.5264
# Episode 129/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.5238
# Episode 130/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.5212
# Episode 131/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.5186
# Episode 132/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.5160
# Episode 133/5000: Total Reward = -5.10, Steps = 50, Epsilon = 0.5134
# Episode 134/5000: Total Reward = -5.70, Steps = 50, Epsilon = 0.5108
# Episode 135/5000: Total Reward = -3.30, Steps = 50, Epsilon = 0.5083
# Episode 136/5000: Total Reward = -3.90, Steps = 50, Epsilon = 0.5058
# Episode 137/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.5032
# Episode 138/5000: Total Reward = -8.70, Steps = 50, Epsilon = 0.5007
# Episode 139/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.4982
# Episode 140/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.4957
# Episode 141/5000: Total Reward = -3.90, Steps = 50, Epsilon = 0.4932
# Episode 142/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.4908
# Episode 143/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.4883
# Episode 144/5000: Total Reward = -2.70, Steps = 50, Epsilon = 0.4859
# Episode 145/5000: Total Reward = -3.30, Steps = 50, Epsilon = 0.4834
# Episode 146/5000: Total Reward = -5.10, Steps = 50, Epsilon = 0.4810
# Episode 147/5000: Total Reward = -3.90, Steps = 50, Epsilon = 0.4786
# Episode 148/5000: Total Reward = -5.70, Steps = 50, Epsilon = 0.4762
# Episode 149/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.4738
# Episode 150/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.4715
# Episode 151/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.4691
# Episode 152/5000: Total Reward = -1.50, Steps = 50, Epsilon = 0.4668
# Episode 153/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.4644
# Episode 154/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.4621
# Episode 155/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.4598
# Episode 156/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.4575
# Episode 157/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.4552
# Episode 158/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.4529
# Episode 159/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.4507
# Episode 160/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.4484
# Episode 161/5000: Total Reward = 1.80, Steps = 53, Epsilon = 0.4462
# Episode 162/5000: Total Reward = -4.50, Steps = 50, Epsilon = 0.4440
# Episode 163/5000: Total Reward = -5.10, Steps = 50, Epsilon = 0.4417
# Episode 164/5000: Total Reward = -2.70, Steps = 50, Epsilon = 0.4395
# Episode 165/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.4373
# Episode 166/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.4351
# Episode 167/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.4330
# Episode 168/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.4308
# Episode 169/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.4286
# Episode 170/5000: Total Reward = -5.70, Steps = 50, Epsilon = 0.4265
# Episode 171/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.4244
# Episode 172/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.4223
# Episode 173/5000: Total Reward = -5.70, Steps = 50, Epsilon = 0.4201
# Episode 174/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.4180
# Episode 175/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.4159
# Episode 176/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.4139
# Episode 177/5000: Total Reward = -5.10, Steps = 50, Epsilon = 0.4118
# Episode 178/5000: Total Reward = -8.70, Steps = 50, Epsilon = 0.4097
# Episode 179/5000: Total Reward = -3.30, Steps = 50, Epsilon = 0.4077
# Episode 180/5000: Total Reward = -3.30, Steps = 50, Epsilon = 0.4057
# Episode 181/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.4036
# Episode 182/5000: Total Reward = -3.30, Steps = 50, Epsilon = 0.4016
# Episode 183/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.3996
# Episode 184/5000: Total Reward = -3.30, Steps = 50, Epsilon = 0.3976
# Episode 185/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.3956
# Episode 186/5000: Total Reward = -8.70, Steps = 50, Epsilon = 0.3936
# Episode 187/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.3917
# Episode 188/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.3897
# Episode 189/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.3878
# Episode 190/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.3858
# Episode 191/5000: Total Reward = -3.90, Steps = 50, Epsilon = 0.3839
# Episode 192/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.3820
# Episode 193/5000: Total Reward = -3.90, Steps = 50, Epsilon = 0.3801
# Episode 194/5000: Total Reward = -3.30, Steps = 50, Epsilon = 0.3782
# Episode 195/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.3763
# Episode 196/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.3744
# Episode 197/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.3725
# Episode 198/5000: Total Reward = -5.70, Steps = 50, Epsilon = 0.3707
# Episode 199/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.3688
# Episode 200/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.3670
# Episode 201/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.3651
# Episode 202/5000: Total Reward = -1.50, Steps = 50, Epsilon = 0.3633
# Episode 203/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.3615
# Episode 204/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.3597
# Episode 205/5000: Total Reward = 2.80, Steps = 57, Epsilon = 0.3579
# Episode 206/5000: Total Reward = -4.50, Steps = 50, Epsilon = 0.3561
# Episode 207/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.3543
# Episode 208/5000: Total Reward = -5.70, Steps = 50, Epsilon = 0.3525
# Episode 209/5000: Total Reward = -2.70, Steps = 50, Epsilon = 0.3508
# Episode 210/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.3490
# Episode 211/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.3473
# Episode 212/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.3455
# Episode 213/5000: Total Reward = -3.90, Steps = 50, Epsilon = 0.3438
# Episode 214/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.3421
# Episode 215/5000: Total Reward = -5.70, Steps = 50, Epsilon = 0.3404
# Episode 216/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.3387
# Episode 217/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.3370
# Episode 218/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.3353
# Episode 219/5000: Total Reward = -2.70, Steps = 50, Epsilon = 0.3336
# Episode 220/5000: Total Reward = -2.10, Steps = 50, Epsilon = 0.3320
# Episode 221/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.3303
# Episode 222/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.3286
# Episode 223/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.3270
# Episode 224/5000: Total Reward = -8.70, Steps = 50, Epsilon = 0.3254
# Episode 225/5000: Total Reward = -9.30, Steps = 50, Epsilon = 0.3237
# Episode 226/5000: Total Reward = -5.70, Steps = 50, Epsilon = 0.3221
# Episode 227/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.3205
# Episode 228/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.3189
# Episode 229/5000: Total Reward = -3.30, Steps = 50, Epsilon = 0.3173
# Episode 230/5000: Total Reward = -3.90, Steps = 50, Epsilon = 0.3157
# Episode 231/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.3141
# Episode 232/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.3126
# Episode 233/5000: Total Reward = -4.50, Steps = 50, Epsilon = 0.3110
# Episode 234/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.3095
# Episode 235/5000: Total Reward = -1.50, Steps = 50, Epsilon = 0.3079
# Episode 236/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.3064
# Episode 237/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.3048
# Episode 238/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.3033
# Episode 239/5000: Total Reward = -3.30, Steps = 50, Epsilon = 0.3018
# Episode 240/5000: Total Reward = -0.30, Steps = 50, Epsilon = 0.3003
# Episode 241/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.2988
# Episode 242/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2973
# Episode 243/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2958
# Episode 244/5000: Total Reward = -4.50, Steps = 50, Epsilon = 0.2943
# Episode 245/5000: Total Reward = -2.70, Steps = 50, Epsilon = 0.2929
# Episode 246/5000: Total Reward = -8.70, Steps = 50, Epsilon = 0.2914
# Episode 247/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2899
# Episode 248/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2885
# Episode 249/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2870
# Episode 250/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2856
# Episode 251/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2842
# Episode 252/5000: Total Reward = -2.70, Steps = 50, Epsilon = 0.2828
# Episode 253/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2813
# Episode 254/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2799
# Episode 255/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2785
# Episode 256/5000: Total Reward = -3.30, Steps = 50, Epsilon = 0.2771
# Episode 257/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2758
# Episode 258/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.2744
# Episode 259/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2730
# Episode 260/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2716
# Episode 261/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2703
# Episode 262/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2689
# Episode 263/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2676
# Episode 264/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2663
# Episode 265/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2649
# Episode 266/5000: Total Reward = -3.90, Steps = 50, Epsilon = 0.2636
# Episode 267/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.2623
# Episode 268/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2610
# Episode 269/5000: Total Reward = 2.70, Steps = 50, Epsilon = 0.2597
# Episode 270/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.2584
# Episode 271/5000: Total Reward = -5.10, Steps = 50, Epsilon = 0.2571
# Episode 272/5000: Total Reward = -2.70, Steps = 50, Epsilon = 0.2558
# Episode 273/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2545
# Episode 274/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2532
# Episode 275/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2520
# Episode 276/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2507
# Episode 277/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2495
# Episode 278/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.2482
# Episode 279/5000: Total Reward = -3.90, Steps = 50, Epsilon = 0.2470
# Episode 280/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2457
# Episode 281/5000: Total Reward = -3.30, Steps = 50, Epsilon = 0.2445
# Episode 282/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2433
# Episode 283/5000: Total Reward = -0.30, Steps = 50, Epsilon = 0.2421
# Episode 284/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2409
# Episode 285/5000: Total Reward = -0.30, Steps = 50, Epsilon = 0.2397
# Episode 286/5000: Total Reward = -5.70, Steps = 50, Epsilon = 0.2385
# Episode 287/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.2373
# Episode 288/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2361
# Episode 289/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2349
# Episode 290/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2337
# Episode 291/5000: Total Reward = -4.50, Steps = 50, Epsilon = 0.2326
# Episode 292/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2314
# Episode 293/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2302
# Episode 294/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2291
# Episode 295/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2279
# Episode 296/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2268
# Episode 297/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2257
# Episode 298/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2245
# Episode 299/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2234
# Episode 300/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2223
# Episode 301/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2212
# Episode 302/5000: Total Reward = -3.30, Steps = 50, Epsilon = 0.2201
# Episode 303/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2190
# Episode 304/5000: Total Reward = -2.70, Steps = 50, Epsilon = 0.2179
# Episode 305/5000: Total Reward = -3.90, Steps = 50, Epsilon = 0.2168
# Episode 306/5000: Total Reward = 3.00, Steps = 53, Epsilon = 0.2157
# Episode 307/5000: Total Reward = -3.30, Steps = 50, Epsilon = 0.2146
# Episode 308/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2136
# Episode 309/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2125
# Episode 310/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.2114
# Episode 311/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2104
# Episode 312/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2093
# Episode 313/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.2083
# Episode 314/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2072
# Episode 315/5000: Total Reward = -1.50, Steps = 50, Epsilon = 0.2062
# Episode 316/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.2052
# Episode 317/5000: Total Reward = -8.70, Steps = 50, Epsilon = 0.2041
# Episode 318/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.2031
# Episode 319/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2021
# Episode 320/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.2011
# Episode 321/5000: Total Reward = -3.90, Steps = 50, Epsilon = 0.2001
# Episode 322/5000: Total Reward = -5.10, Steps = 50, Epsilon = 0.1991
# Episode 323/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.1981
# Episode 324/5000: Total Reward = -2.10, Steps = 50, Epsilon = 0.1971
# Episode 325/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1961
# Episode 326/5000: Total Reward = -0.30, Steps = 50, Epsilon = 0.1951
# Episode 327/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1942
# Episode 328/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1932
# Episode 329/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1922
# Episode 330/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1913
# Episode 331/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1903
# Episode 332/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1893
# Episode 333/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1884
# Episode 334/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.1875
# Episode 335/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1865
# Episode 336/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1856
# Episode 337/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1847
# Episode 338/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1837
# Episode 339/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1828
# Episode 340/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1819
# Episode 341/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1810
# Episode 342/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1801
# Episode 343/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1792
# Episode 344/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.1783
# Episode 345/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1774
# Episode 346/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1765
# Episode 347/5000: Total Reward = -2.10, Steps = 50, Epsilon = 0.1756
# Episode 348/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1748
# Episode 349/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1739
# Episode 350/5000: Total Reward = 0.30, Steps = 50, Epsilon = 0.1730
# Episode 351/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1721
# Episode 352/5000: Total Reward = -4.50, Steps = 50, Epsilon = 0.1713
# Episode 353/5000: Total Reward = -5.10, Steps = 50, Epsilon = 0.1704
# Episode 354/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1696
# Episode 355/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1687
# Episode 356/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.1679
# Episode 357/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.1670
# Episode 358/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1662
# Episode 359/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1654
# Episode 360/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.1646
# Episode 361/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1637
# Episode 362/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1629
# Episode 363/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1621
# Episode 364/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1613
# Episode 365/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1605
# Episode 366/5000: Total Reward = -3.90, Steps = 50, Epsilon = 0.1597
# Episode 367/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1589
# Episode 368/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.1581
# Episode 369/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.1573
# Episode 370/5000: Total Reward = -2.70, Steps = 50, Epsilon = 0.1565
# Episode 371/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.1557
# Episode 372/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1549
# Episode 373/5000: Total Reward = -2.10, Steps = 50, Epsilon = 0.1542
# Episode 374/5000: Total Reward = 2.30, Steps = 52, Epsilon = 0.1534
# Episode 375/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1526
# Episode 376/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.1519
# Episode 377/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1511
# Episode 378/5000: Total Reward = -3.50, Steps = 60, Epsilon = 0.1504
# Episode 379/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1496
# Episode 380/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1489
# Episode 381/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1481
# Episode 382/5000: Total Reward = -3.30, Steps = 50, Epsilon = 0.1474
# Episode 383/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.1466
# Episode 384/5000: Total Reward = 1.00, Steps = 51, Epsilon = 0.1459
# Episode 385/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1452
# Episode 386/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1444
# Episode 387/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1437
# Episode 388/5000: Total Reward = -3.40, Steps = 61, Epsilon = 0.1430
# Episode 389/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1423
# Episode 390/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1416
# Episode 391/5000: Total Reward = 2.70, Steps = 50, Epsilon = 0.1409
# Episode 392/5000: Total Reward = 1.30, Steps = 54, Epsilon = 0.1402
# Episode 393/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1395
# Episode 394/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1388
# Episode 395/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1381
# Episode 396/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1374
# Episode 397/5000: Total Reward = -8.70, Steps = 50, Epsilon = 0.1367
# Episode 398/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1360
# Episode 399/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1353
# Episode 400/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1347
# Episode 401/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.1340
# Episode 402/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1333
# Episode 403/5000: Total Reward = -5.70, Steps = 50, Epsilon = 0.1326
# Episode 404/5000: Total Reward = -2.70, Steps = 50, Epsilon = 0.1320
# Episode 405/5000: Total Reward = -3.90, Steps = 50, Epsilon = 0.1313
# Episode 406/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1307
# Episode 407/5000: Total Reward = -5.70, Steps = 50, Epsilon = 0.1300
# Episode 408/5000: Total Reward = -2.70, Steps = 50, Epsilon = 0.1294
# Episode 409/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1287
# Episode 410/5000: Total Reward = 0.90, Steps = 65, Epsilon = 0.1281
# Episode 411/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.1274
# Episode 412/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1268
# Episode 413/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1262
# Episode 414/5000: Total Reward = -3.30, Steps = 65, Epsilon = 0.1255
# Episode 415/5000: Total Reward = -1.60, Steps = 61, Epsilon = 0.1249
# Episode 416/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.1243
# Episode 417/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1237
# Episode 418/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1230
# Episode 419/5000: Total Reward = -0.30, Steps = 50, Epsilon = 0.1224
# Episode 420/5000: Total Reward = 0.30, Steps = 50, Epsilon = 0.1218
# Episode 421/5000: Total Reward = -3.90, Steps = 50, Epsilon = 0.1212
# Episode 422/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1206
# Episode 423/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1200
# Episode 424/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1194
# Episode 425/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1188
# Episode 426/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1182
# Episode 427/5000: Total Reward = 2.10, Steps = 50, Epsilon = 0.1176
# Episode 428/5000: Total Reward = 2.70, Steps = 50, Epsilon = 0.1170
# Episode 429/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1164
# Episode 430/5000: Total Reward = -4.50, Steps = 50, Epsilon = 0.1159
# Episode 431/5000: Total Reward = -2.10, Steps = 50, Epsilon = 0.1153
# Episode 432/5000: Total Reward = 2.30, Steps = 58, Epsilon = 0.1147
# Episode 433/5000: Total Reward = 1.00, Steps = 57, Epsilon = 0.1141
# Episode 434/5000: Total Reward = 0.30, Steps = 50, Epsilon = 0.1136
# Episode 435/5000: Total Reward = -1.50, Steps = 50, Epsilon = 0.1130
# Episode 436/5000: Total Reward = 2.00, Steps = 61, Epsilon = 0.1124
# Episode 437/5000: Total Reward = 1.90, Steps = 54, Epsilon = 0.1119
# Episode 438/5000: Total Reward = 4.90, Steps = 63, Epsilon = 0.1113
# Episode 439/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1107
# Episode 440/5000: Total Reward = 0.80, Steps = 31, Epsilon = 0.1102
# Episode 441/5000: Total Reward = 2.70, Steps = 65, Epsilon = 0.1096
# Episode 442/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1091
# Episode 443/5000: Total Reward = -1.50, Steps = 50, Epsilon = 0.1085
# Episode 444/5000: Total Reward = -1.30, Steps = 52, Epsilon = 0.1080
# Episode 445/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1075
# Episode 446/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.1069
# Episode 447/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1064
# Episode 448/5000: Total Reward = 5.00, Steps = 64, Epsilon = 0.1059
# Episode 449/5000: Total Reward = 2.10, Steps = 50, Epsilon = 0.1053
# Episode 450/5000: Total Reward = -3.30, Steps = 50, Epsilon = 0.1048
# Episode 451/5000: Total Reward = -1.40, Steps = 51, Epsilon = 0.1043
# Episode 452/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.1038
# Episode 453/5000: Total Reward = 1.50, Steps = 50, Epsilon = 0.1032
# Episode 454/5000: Total Reward = 1.20, Steps = 53, Epsilon = 0.1027
# Episode 455/5000: Total Reward = 3.10, Steps = 63, Epsilon = 0.1022
# Episode 456/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1017
# Episode 457/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.1012
# Episode 458/5000: Total Reward = -3.30, Steps = 50, Epsilon = 0.1007
# Episode 459/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.1002
# Episode 460/5000: Total Reward = 1.50, Steps = 50, Epsilon = 0.0997
# Episode 461/5000: Total Reward = 2.10, Steps = 50, Epsilon = 0.0992
# Episode 462/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0987
# Episode 463/5000: Total Reward = 2.10, Steps = 50, Epsilon = 0.0982
# Episode 464/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0977
# Episode 465/5000: Total Reward = -0.30, Steps = 50, Epsilon = 0.0972
# Episode 466/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0967
# Episode 467/5000: Total Reward = -0.30, Steps = 50, Epsilon = 0.0962
# Episode 468/5000: Total Reward = 0.30, Steps = 50, Epsilon = 0.0958
# Episode 469/5000: Total Reward = -8.70, Steps = 50, Epsilon = 0.0953
# Episode 470/5000: Total Reward = -4.50, Steps = 50, Epsilon = 0.0948
# Episode 471/5000: Total Reward = -0.20, Steps = 57, Epsilon = 0.0943
# Episode 472/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0939
# Episode 473/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0934
# Episode 474/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0929
# Episode 475/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0925
# Episode 476/5000: Total Reward = 0.90, Steps = 50, Epsilon = 0.0920
# Episode 477/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0915
# Episode 478/5000: Total Reward = 2.30, Steps = 52, Epsilon = 0.0911
# Episode 479/5000: Total Reward = 1.80, Steps = 68, Epsilon = 0.0906
# Episode 480/5000: Total Reward = 0.90, Steps = 50, Epsilon = 0.0902
# Episode 481/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0897
# Episode 482/5000: Total Reward = 2.10, Steps = 50, Epsilon = 0.0893
# Episode 483/5000: Total Reward = -0.30, Steps = 50, Epsilon = 0.0888
# Episode 484/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.0884
# Episode 485/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0879
# Episode 486/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.0875
# Episode 487/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0871
# Episode 488/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0866
# Episode 489/5000: Total Reward = -3.30, Steps = 50, Epsilon = 0.0862
# Episode 490/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0858
# Episode 491/5000: Total Reward = 0.40, Steps = 51, Epsilon = 0.0853
# Episode 492/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0849
# Episode 493/5000: Total Reward = -8.70, Steps = 50, Epsilon = 0.0845
# Episode 494/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0841
# Episode 495/5000: Total Reward = 0.30, Steps = 50, Epsilon = 0.0836
# Episode 496/5000: Total Reward = -1.20, Steps = 62, Epsilon = 0.0832
# Episode 497/5000: Total Reward = -0.30, Steps = 50, Epsilon = 0.0828
# Episode 498/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0824
# Episode 499/5000: Total Reward = -2.80, Steps = 61, Epsilon = 0.0820
# Episode 500/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0816
# Episode 501/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0812
# Episode 502/5000: Total Reward = -5.10, Steps = 50, Epsilon = 0.0808
# Episode 503/5000: Total Reward = 2.50, Steps = 54, Epsilon = 0.0804
# Episode 504/5000: Total Reward = -9.30, Steps = 50, Epsilon = 0.0800
# Episode 505/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0796
# Episode 506/5000: Total Reward = -1.50, Steps = 50, Epsilon = 0.0792
# Episode 507/5000: Total Reward = 1.50, Steps = 50, Epsilon = 0.0788
# Episode 508/5000: Total Reward = 0.90, Steps = 50, Epsilon = 0.0784
# Episode 509/5000: Total Reward = 2.80, Steps = 57, Epsilon = 0.0780
# Episode 510/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0776
# Episode 511/5000: Total Reward = 1.50, Steps = 50, Epsilon = 0.0772
# Episode 512/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0768
# Episode 513/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0764
# Episode 514/5000: Total Reward = 2.10, Steps = 50, Epsilon = 0.0760
# Episode 515/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0757
# Episode 516/5000: Total Reward = 2.20, Steps = 51, Epsilon = 0.0753
# Episode 517/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0749
# Episode 518/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0745
# Episode 519/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0742
# Episode 520/5000: Total Reward = 2.80, Steps = 51, Epsilon = 0.0738
# Episode 521/5000: Total Reward = 2.10, Steps = 50, Epsilon = 0.0734
# Episode 522/5000: Total Reward = 3.00, Steps = 53, Epsilon = 0.0731
# Episode 523/5000: Total Reward = 0.30, Steps = 50, Epsilon = 0.0727
# Episode 524/5000: Total Reward = -0.30, Steps = 50, Epsilon = 0.0723
# Episode 525/5000: Total Reward = 0.60, Steps = 59, Epsilon = 0.0720
# Episode 526/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0716
# Episode 527/5000: Total Reward = 1.20, Steps = 53, Epsilon = 0.0712
# Episode 528/5000: Total Reward = 2.00, Steps = 64, Epsilon = 0.0709
# Episode 529/5000: Total Reward = 3.10, Steps = 54, Epsilon = 0.0705
# Episode 530/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0702
# Episode 531/5000: Total Reward = 2.20, Steps = 51, Epsilon = 0.0698
# Episode 532/5000: Total Reward = 3.00, Steps = 53, Epsilon = 0.0695
# Episode 533/5000: Total Reward = 3.10, Steps = 54, Epsilon = 0.0691
# Episode 534/5000: Total Reward = -2.10, Steps = 50, Epsilon = 0.0688
# Episode 535/5000: Total Reward = 2.50, Steps = 54, Epsilon = 0.0684
# Episode 536/5000: Total Reward = 3.80, Steps = 64, Epsilon = 0.0681
# Episode 537/5000: Total Reward = 1.50, Steps = 56, Epsilon = 0.0678
# Episode 538/5000: Total Reward = 3.00, Steps = 86, Epsilon = 0.0674
# Episode 539/5000: Total Reward = 2.90, Steps = 52, Epsilon = 0.0671
# Episode 540/5000: Total Reward = 3.00, Steps = 53, Epsilon = 0.0668
# Episode 541/5000: Total Reward = -0.10, Steps = 52, Epsilon = 0.0664
# Episode 542/5000: Total Reward = -3.40, Steps = 61, Epsilon = 0.0661
# Episode 543/5000: Total Reward = 3.00, Steps = 86, Epsilon = 0.0658
# Episode 544/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.0654
# Episode 545/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0651
# Episode 546/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0648
# Episode 547/5000: Total Reward = 3.20, Steps = 64, Epsilon = 0.0645
# Episode 548/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0641
# Episode 549/5000: Total Reward = 5.90, Steps = 67, Epsilon = 0.0638
# Episode 550/5000: Total Reward = 0.90, Steps = 50, Epsilon = 0.0635
# Episode 551/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0632
# Episode 552/5000: Total Reward = -0.80, Steps = 51, Epsilon = 0.0629
# Episode 553/5000: Total Reward = -5.70, Steps = 50, Epsilon = 0.0625
# Episode 554/5000: Total Reward = -1.30, Steps = 58, Epsilon = 0.0622
# Episode 555/5000: Total Reward = 2.70, Steps = 50, Epsilon = 0.0619
# Episode 556/5000: Total Reward = 2.50, Steps = 54, Epsilon = 0.0616
# Episode 557/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0613
# Episode 558/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0610
# Episode 559/5000: Total Reward = -3.90, Steps = 50, Epsilon = 0.0607
# Episode 560/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0604
# Episode 561/5000: Total Reward = 1.50, Steps = 95, Epsilon = 0.0601
# Episode 562/5000: Total Reward = -0.30, Steps = 50, Epsilon = 0.0598
# Episode 563/5000: Total Reward = 6.10, Steps = 93, Epsilon = 0.0595
# Episode 564/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0592
# Episode 565/5000: Total Reward = 1.00, Steps = 51, Epsilon = 0.0589
# Episode 566/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0586
# Episode 567/5000: Total Reward = 0.90, Steps = 50, Epsilon = 0.0583
# Episode 568/5000: Total Reward = 0.30, Steps = 50, Epsilon = 0.0580
# Episode 569/5000: Total Reward = 0.90, Steps = 50, Epsilon = 0.0577
# Episode 570/5000: Total Reward = 2.30, Steps = 52, Epsilon = 0.0574
# Episode 571/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0571
# Episode 572/5000: Total Reward = 1.50, Steps = 50, Epsilon = 0.0569
# Episode 573/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0566
# Episode 574/5000: Total Reward = 2.70, Steps = 50, Epsilon = 0.0563
# Episode 575/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0560
# Episode 576/5000: Total Reward = 3.00, Steps = 53, Epsilon = 0.0557
# Episode 577/5000: Total Reward = 2.90, Steps = 52, Epsilon = 0.0555
# Episode 578/5000: Total Reward = -0.30, Steps = 56, Epsilon = 0.0552
# Episode 579/5000: Total Reward = 1.50, Steps = 50, Epsilon = 0.0549
# Episode 580/5000: Total Reward = 4.90, Steps = 63, Epsilon = 0.0546
# Episode 581/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0544
# Episode 582/5000: Total Reward = -0.10, Steps = 52, Epsilon = 0.0541
# Episode 583/5000: Total Reward = 1.50, Steps = 50, Epsilon = 0.0538
# Episode 584/5000: Total Reward = 2.80, Steps = 51, Epsilon = 0.0535
# Episode 585/5000: Total Reward = 2.80, Steps = 51, Epsilon = 0.0533
# Episode 586/5000: Total Reward = 1.30, Steps = 54, Epsilon = 0.0530
# Episode 587/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0527
# Episode 588/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0525
# Episode 589/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.0522
# Episode 590/5000: Total Reward = -2.10, Steps = 50, Epsilon = 0.0520
# Episode 591/5000: Total Reward = 0.10, Steps = 54, Epsilon = 0.0517
# Episode 592/5000: Total Reward = -2.10, Steps = 50, Epsilon = 0.0514
# Episode 593/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.0512
# Episode 594/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0509
# Episode 595/5000: Total Reward = -1.60, Steps = 55, Epsilon = 0.0507
# Episode 596/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0504
# Episode 597/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0502
# Episode 598/5000: Total Reward = 2.70, Steps = 50, Epsilon = 0.0499
# Episode 599/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0497
# Episode 600/5000: Total Reward = 2.80, Steps = 51, Epsilon = 0.0494
# Episode 601/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0492
# Episode 602/5000: Total Reward = 0.30, Steps = 50, Epsilon = 0.0489
# Episode 603/5000: Total Reward = 0.90, Steps = 50, Epsilon = 0.0487
# Episode 604/5000: Total Reward = 1.50, Steps = 50, Epsilon = 0.0484
# Episode 605/5000: Total Reward = 2.10, Steps = 44, Epsilon = 0.0482
# Episode 606/5000: Total Reward = -0.30, Steps = 50, Epsilon = 0.0479
# Episode 607/5000: Total Reward = 1.50, Steps = 50, Epsilon = 0.0477
# Episode 608/5000: Total Reward = 3.10, Steps = 54, Epsilon = 0.0475
# Episode 609/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0472
# Episode 610/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.0470
# Episode 611/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.0468
# Episode 612/5000: Total Reward = 2.80, Steps = 51, Epsilon = 0.0465
# Episode 613/5000: Total Reward = 1.90, Steps = 54, Epsilon = 0.0463
# Episode 614/5000: Total Reward = 2.70, Steps = 50, Epsilon = 0.0461
# Episode 615/5000: Total Reward = 3.10, Steps = 54, Epsilon = 0.0458
# Episode 616/5000: Total Reward = -0.30, Steps = 50, Epsilon = 0.0456
# Episode 617/5000: Total Reward = 2.50, Steps = 60, Epsilon = 0.0454
# Episode 618/5000: Total Reward = 2.10, Steps = 50, Epsilon = 0.0452
# Episode 619/5000: Total Reward = 0.30, Steps = 50, Epsilon = 0.0449
# Episode 620/5000: Total Reward = -3.30, Steps = 50, Epsilon = 0.0447
# Episode 621/5000: Total Reward = 0.30, Steps = 50, Epsilon = 0.0445
# Episode 622/5000: Total Reward = 0.30, Steps = 50, Epsilon = 0.0443
# Episode 623/5000: Total Reward = 1.70, Steps = 52, Epsilon = 0.0440
# Episode 624/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0438
# Episode 625/5000: Total Reward = -3.30, Steps = 50, Epsilon = 0.0436
# Episode 626/5000: Total Reward = 1.60, Steps = 51, Epsilon = 0.0434
# Episode 627/5000: Total Reward = 2.50, Steps = 54, Epsilon = 0.0432
# Episode 628/5000: Total Reward = 0.30, Steps = 50, Epsilon = 0.0429
# Episode 629/5000: Total Reward = 1.50, Steps = 50, Epsilon = 0.0427
# Episode 630/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0425
# Episode 631/5000: Total Reward = 1.50, Steps = 50, Epsilon = 0.0423
# Episode 632/5000: Total Reward = 2.70, Steps = 50, Epsilon = 0.0421
# Episode 633/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0419
# Episode 634/5000: Total Reward = 2.90, Steps = 52, Epsilon = 0.0417
# Episode 635/5000: Total Reward = -2.10, Steps = 56, Epsilon = 0.0415
# Episode 636/5000: Total Reward = -3.00, Steps = 86, Epsilon = 0.0413
# Episode 637/5000: Total Reward = -4.50, Steps = 50, Epsilon = 0.0410
# Episode 638/5000: Total Reward = 1.50, Steps = 50, Epsilon = 0.0408
# Episode 639/5000: Total Reward = 2.30, Steps = 52, Epsilon = 0.0406
# Episode 640/5000: Total Reward = 1.90, Steps = 54, Epsilon = 0.0404
# Episode 641/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0402
# Episode 642/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0400
# Episode 643/5000: Total Reward = 2.70, Steps = 50, Epsilon = 0.0398
# Episode 644/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0396
# Episode 645/5000: Total Reward = 1.50, Steps = 50, Epsilon = 0.0394
# Episode 646/5000: Total Reward = -5.70, Steps = 50, Epsilon = 0.0392
# Episode 647/5000: Total Reward = -1.90, Steps = 58, Epsilon = 0.0390
# Episode 648/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.0388
# Episode 649/5000: Total Reward = 1.50, Steps = 50, Epsilon = 0.0387
# Episode 650/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0385
# Episode 651/5000: Total Reward = 2.10, Steps = 50, Epsilon = 0.0383
# Episode 652/5000: Total Reward = -9.30, Steps = 50, Epsilon = 0.0381
# Episode 653/5000: Total Reward = 1.70, Steps = 52, Epsilon = 0.0379
# Episode 654/5000: Total Reward = -4.50, Steps = 50, Epsilon = 0.0377
# Episode 655/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0375
# Episode 656/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0373
# Episode 657/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0371
# Episode 658/5000: Total Reward = -0.30, Steps = 50, Epsilon = 0.0369
# Episode 659/5000: Total Reward = 1.50, Steps = 50, Epsilon = 0.0368
# Episode 660/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0366
# Episode 661/5000: Total Reward = -0.30, Steps = 50, Epsilon = 0.0364
# Episode 662/5000: Total Reward = 0.30, Steps = 50, Epsilon = 0.0362
# Episode 663/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0360
# Episode 664/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0359
# Episode 665/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0357
# Episode 666/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0355
# Episode 667/5000: Total Reward = 0.90, Steps = 50, Epsilon = 0.0353
# Episode 668/5000: Total Reward = 0.90, Steps = 50, Epsilon = 0.0351
# Episode 669/5000: Total Reward = -0.30, Steps = 50, Epsilon = 0.0350
# Episode 670/5000: Total Reward = 3.00, Steps = 53, Epsilon = 0.0348
# Episode 671/5000: Total Reward = -0.10, Steps = 52, Epsilon = 0.0346
# Episode 672/5000: Total Reward = 2.30, Steps = 52, Epsilon = 0.0344
# Episode 673/5000: Total Reward = 3.00, Steps = 53, Epsilon = 0.0343
# Episode 674/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0341
# Episode 675/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0339
# Episode 676/5000: Total Reward = 6.50, Steps = 91, Epsilon = 0.0338
# Episode 677/5000: Total Reward = 4.00, Steps = 66, Epsilon = 0.0336
# Episode 678/5000: Total Reward = 3.00, Steps = 53, Epsilon = 0.0334
# Episode 679/5000: Total Reward = 1.80, Steps = 68, Epsilon = 0.0333
# Episode 680/5000: Total Reward = 2.00, Steps = 61, Epsilon = 0.0331
# Episode 681/5000: Total Reward = 2.20, Steps = 51, Epsilon = 0.0329
# Episode 682/5000: Total Reward = -0.30, Steps = 50, Epsilon = 0.0328
# Episode 683/5000: Total Reward = -1.70, Steps = 60, Epsilon = 0.0326
# Episode 684/5000: Total Reward = 2.40, Steps = 53, Epsilon = 0.0324
# Episode 685/5000: Total Reward = 3.20, Steps = 55, Epsilon = 0.0323
# Episode 686/5000: Total Reward = 2.10, Steps = 56, Epsilon = 0.0321
# Episode 687/5000: Total Reward = 2.40, Steps = 53, Epsilon = 0.0319
# Episode 688/5000: Total Reward = 2.40, Steps = 92, Epsilon = 0.0318
# Episode 689/5000: Total Reward = 7.10, Steps = 100, Epsilon = 0.0316
# Episode 690/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0315
# Episode 691/5000: Total Reward = 2.30, Steps = 52, Epsilon = 0.0313
# Episode 692/5000: Total Reward = 3.10, Steps = 54, Epsilon = 0.0312
# Episode 693/5000: Total Reward = 3.00, Steps = 53, Epsilon = 0.0310
# Episode 694/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0308
# Episode 695/5000: Total Reward = 6.10, Steps = 69, Epsilon = 0.0307
# Episode 696/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0305
# Episode 697/5000: Total Reward = 1.50, Steps = 50, Epsilon = 0.0304
# Episode 698/5000: Total Reward = 2.50, Steps = 54, Epsilon = 0.0302
# Episode 699/5000: Total Reward = -5.10, Steps = 50, Epsilon = 0.0301
# Episode 700/5000: Total Reward = 3.10, Steps = 54, Epsilon = 0.0299
# ...
# Episode 4774/5000: Total Reward = 2.00, Steps = 61, Epsilon = 0.0100
# Episode 4775/5000: Total Reward = -6.90, Steps = 50, Epsilon = 0.0100
# Episode 4776/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4777/5000: Total Reward = -2.50, Steps = 58, Epsilon = 0.0100
# Episode 4778/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4779/5000: Total Reward = 0.30, Steps = 50, Epsilon = 0.0100
# Episode 4780/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4781/5000: Total Reward = -1.00, Steps = 64, Epsilon = 0.0100
# Episode 4782/5000: Total Reward = -5.70, Steps = 50, Epsilon = 0.0100
# Episode 4783/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4784/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.0100
# Episode 4785/5000: Total Reward = 0.10, Steps = 63, Epsilon = 0.0100
# Episode 4786/5000: Total Reward = 1.80, Steps = 86, Epsilon = 0.0100
# Episode 4787/5000: Total Reward = 0.30, Steps = 50, Epsilon = 0.0100
# Episode 4788/5000: Total Reward = 0.30, Steps = 50, Epsilon = 0.0100
# Episode 4789/5000: Total Reward = 0.80, Steps = 64, Epsilon = 0.0100
# Episode 4790/5000: Total Reward = -0.60, Steps = 53, Epsilon = 0.0100
# Episode 4791/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4792/5000: Total Reward = 0.60, Steps = 68, Epsilon = 0.0100
# Episode 4793/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4794/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4795/5000: Total Reward = -4.20, Steps = 86, Epsilon = 0.0100
# Episode 4796/5000: Total Reward = -1.80, Steps = 86, Epsilon = 0.0100
# Episode 4797/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4798/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4799/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4800/5000: Total Reward = 1.80, Steps = 86, Epsilon = 0.0100
# Episode 4801/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4802/5000: Total Reward = 0.30, Steps = 50, Epsilon = 0.0100
# Episode 4803/5000: Total Reward = -0.40, Steps = 61, Epsilon = 0.0100
# Episode 4804/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4805/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4806/5000: Total Reward = 1.20, Steps = 86, Epsilon = 0.0100
# Episode 4807/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4808/5000: Total Reward = 5.50, Steps = 69, Epsilon = 0.0100
# Episode 4809/5000: Total Reward = -1.20, Steps = 62, Epsilon = 0.0100
# Episode 4810/5000: Total Reward = 4.20, Steps = 62, Epsilon = 0.0100
# Episode 4811/5000: Total Reward = -1.70, Steps = 63, Epsilon = 0.0100
# Episode 4812/5000: Total Reward = 0.10, Steps = 54, Epsilon = 0.0100
# Episode 4813/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4814/5000: Total Reward = 0.60, Steps = 86, Epsilon = 0.0100
# Episode 4815/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4816/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4817/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4818/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4819/5000: Total Reward = 1.50, Steps = 50, Epsilon = 0.0100
# Episode 4820/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4821/5000: Total Reward = -4.50, Steps = 98, Epsilon = 0.0100
# Episode 4822/5000: Total Reward = 1.90, Steps = 63, Epsilon = 0.0100
# Episode 4823/5000: Total Reward = -2.30, Steps = 60, Epsilon = 0.0100
# Episode 4824/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4825/5000: Total Reward = -1.80, Steps = 86, Epsilon = 0.0100
# Episode 4826/5000: Total Reward = -2.90, Steps = 87, Epsilon = 0.0100
# Episode 4827/5000: Total Reward = -0.10, Steps = 67, Epsilon = 0.0100
# Episode 4828/5000: Total Reward = 2.60, Steps = 64, Epsilon = 0.0100
# Episode 4829/5000: Total Reward = -4.80, Steps = 86, Epsilon = 0.0100
# Episode 4830/5000: Total Reward = -3.60, Steps = 86, Epsilon = 0.0100
# Episode 4831/5000: Total Reward = -4.50, Steps = 98, Epsilon = 0.0100
# Episode 4832/5000: Total Reward = -0.70, Steps = 67, Epsilon = 0.0100
# Episode 4833/5000: Total Reward = 0.90, Steps = 50, Epsilon = 0.0100
# Episode 4834/5000: Total Reward = 2.00, Steps = 43, Epsilon = 0.0100
# Episode 4835/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4836/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.0100
# Episode 4837/5000: Total Reward = 5.40, Steps = 62, Epsilon = 0.0100
# Episode 4838/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4839/5000: Total Reward = -5.70, Steps = 50, Epsilon = 0.0100
# Episode 4840/5000: Total Reward = -1.90, Steps = 58, Epsilon = 0.0100
# Episode 4841/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4842/5000: Total Reward = -4.50, Steps = 50, Epsilon = 0.0100
# Episode 4843/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4844/5000: Total Reward = -1.70, Steps = 60, Epsilon = 0.0100
# Episode 4845/5000: Total Reward = 1.50, Steps = 65, Epsilon = 0.0100
# Episode 4846/5000: Total Reward = -1.00, Steps = 64, Epsilon = 0.0100
# Episode 4847/5000: Total Reward = 0.90, Steps = 50, Epsilon = 0.0100
# Episode 4848/5000: Total Reward = 0.30, Steps = 50, Epsilon = 0.0100
# Episode 4849/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4850/5000: Total Reward = 1.60, Steps = 51, Epsilon = 0.0100
# Episode 4851/5000: Total Reward = -2.30, Steps = 63, Epsilon = 0.0100
# Episode 4852/5000: Total Reward = 1.50, Steps = 50, Epsilon = 0.0100
# Episode 4853/5000: Total Reward = 1.00, Steps = 66, Epsilon = 0.0100
# Episode 4854/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4855/5000: Total Reward = -2.10, Steps = 50, Epsilon = 0.0100
# Episode 4856/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4857/5000: Total Reward = -1.90, Steps = 52, Epsilon = 0.0100
# Episode 4858/5000: Total Reward = 3.90, Steps = 95, Epsilon = 0.0100
# Episode 4859/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4860/5000: Total Reward = 2.00, Steps = 55, Epsilon = 0.0100
# Episode 4861/5000: Total Reward = 3.30, Steps = 122, Epsilon = 0.0100
# Episode 4862/5000: Total Reward = 0.30, Steps = 50, Epsilon = 0.0100
# Episode 4863/5000: Total Reward = -1.50, Steps = 56, Epsilon = 0.0100
# Episode 4864/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4865/5000: Total Reward = 1.90, Steps = 87, Epsilon = 0.0100
# Episode 4866/5000: Total Reward = -7.50, Steps = 50, Epsilon = 0.0100
# Episode 4867/5000: Total Reward = -2.70, Steps = 56, Epsilon = 0.0100
# Episode 4868/5000: Total Reward = -0.30, Steps = 50, Epsilon = 0.0100
# Episode 4869/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4870/5000: Total Reward = 1.40, Steps = 103, Epsilon = 0.0100
# Episode 4871/5000: Total Reward = 3.00, Steps = 86, Epsilon = 0.0100
# Episode 4872/5000: Total Reward = 1.90, Steps = 132, Epsilon = 0.0100
# Episode 4873/5000: Total Reward = -1.10, Steps = 63, Epsilon = 0.0100
# Episode 4874/5000: Total Reward = -3.30, Steps = 122, Epsilon = 0.0100
# Episode 4875/5000: Total Reward = 0.90, Steps = 50, Epsilon = 0.0100
# Episode 4876/5000: Total Reward = 3.00, Steps = 68, Epsilon = 0.0100
# Episode 4877/5000: Total Reward = 4.60, Steps = 66, Epsilon = 0.0100
# Episode 4878/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4879/5000: Total Reward = 1.20, Steps = 86, Epsilon = 0.0100
# Episode 4880/5000: Total Reward = -0.30, Steps = 50, Epsilon = 0.0100
# Episode 4881/5000: Total Reward = 1.80, Steps = 86, Epsilon = 0.0100
# Episode 4882/5000: Total Reward = 2.50, Steps = 60, Epsilon = 0.0100
# Episode 4883/5000: Total Reward = -0.90, Steps = 56, Epsilon = 0.0100
# Episode 4884/5000: Total Reward = 0.90, Steps = 50, Epsilon = 0.0100
# Episode 4885/5000: Total Reward = 3.10, Steps = 135, Epsilon = 0.0100
# Episode 4886/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4887/5000: Total Reward = 4.80, Steps = 68, Epsilon = 0.0100
# Episode 4888/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4889/5000: Total Reward = -8.10, Steps = 50, Epsilon = 0.0100
# Episode 4890/5000: Total Reward = -6.30, Steps = 50, Epsilon = 0.0100
# Episode 4891/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4892/5000: Total Reward = 5.40, Steps = 62, Epsilon = 0.0100
# Episode 4893/5000: Total Reward = -3.60, Steps = 86, Epsilon = 0.0100
# Episode 4894/5000: Total Reward = 1.50, Steps = 50, Epsilon = 0.0100
# Episode 4895/5000: Total Reward = 1.50, Steps = 50, Epsilon = 0.0100
# Episode 4896/5000: Total Reward = 0.90, Steps = 50, Epsilon = 0.0100
# Episode 4897/5000: Total Reward = 2.40, Steps = 86, Epsilon = 0.0100
# Episode 4898/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4899/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4900/5000: Total Reward = 2.00, Steps = 61, Epsilon = 0.0100
# Episode 4901/5000: Total Reward = 2.50, Steps = 42, Epsilon = 0.0100
# Episode 4902/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4903/5000: Total Reward = 2.50, Steps = 60, Epsilon = 0.0100
# Episode 4904/5000: Total Reward = 3.10, Steps = 60, Epsilon = 0.0100
# Episode 4905/5000: Total Reward = 1.50, Steps = 122, Epsilon = 0.0100
# Episode 4906/5000: Total Reward = -2.80, Steps = 61, Epsilon = 0.0100
# Episode 4907/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4908/5000: Total Reward = 0.00, Steps = 86, Epsilon = 0.0100
# Episode 4909/5000: Total Reward = -0.60, Steps = 86, Epsilon = 0.0100
# Episode 4910/5000: Total Reward = 2.40, Steps = 68, Epsilon = 0.0100
# Episode 4911/5000: Total Reward = 3.10, Steps = 63, Epsilon = 0.0100
# Episode 4912/5000: Total Reward = 3.30, Steps = 65, Epsilon = 0.0100
# Episode 4913/5000: Total Reward = 0.80, Steps = 31, Epsilon = 0.0100
# Episode 4914/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4915/5000: Total Reward = 0.30, Steps = 50, Epsilon = 0.0100
# Episode 4916/5000: Total Reward = 6.20, Steps = 70, Epsilon = 0.0100
# Episode 4917/5000: Total Reward = 1.50, Steps = 50, Epsilon = 0.0100
# Episode 4918/5000: Total Reward = 0.30, Steps = 50, Epsilon = 0.0100
# Episode 4919/5000: Total Reward = -0.30, Steps = 50, Epsilon = 0.0100
# Episode 4920/5000: Total Reward = -0.20, Steps = 105, Epsilon = 0.0100
# Episode 4921/5000: Total Reward = -0.30, Steps = 50, Epsilon = 0.0100
# Episode 4922/5000: Total Reward = 5.40, Steps = 62, Epsilon = 0.0100
# Episode 4923/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4924/5000: Total Reward = 3.40, Steps = 66, Epsilon = 0.0100
# Episode 4925/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4926/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4927/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4928/5000: Total Reward = -0.00, Steps = 86, Epsilon = 0.0100
# Episode 4929/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4930/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4931/5000: Total Reward = -9.30, Steps = 50, Epsilon = 0.0100
# Episode 4932/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4933/5000: Total Reward = 0.90, Steps = 50, Epsilon = 0.0100
# Episode 4934/5000: Total Reward = 0.40, Steps = 51, Epsilon = 0.0100
# Episode 4935/5000: Total Reward = 3.70, Steps = 60, Epsilon = 0.0100
# Episode 4936/5000: Total Reward = -1.00, Steps = 61, Epsilon = 0.0100
# Episode 4937/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4938/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4939/5000: Total Reward = 3.60, Steps = 86, Epsilon = 0.0100
# Episode 4940/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4941/5000: Total Reward = 0.90, Steps = 50, Epsilon = 0.0100
# Episode 4942/5000: Total Reward = -1.90, Steps = 58, Epsilon = 0.0100
# Episode 4943/5000: Total Reward = -2.10, Steps = 56, Epsilon = 0.0100
# Episode 4944/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4945/5000: Total Reward = 1.80, Steps = 86, Epsilon = 0.0100
# Episode 4946/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4947/5000: Total Reward = 3.40, Steps = 57, Epsilon = 0.0100
# Episode 4948/5000: Total Reward = -0.50, Steps = 63, Epsilon = 0.0100
# Episode 4949/5000: Total Reward = -0.70, Steps = 100, Epsilon = 0.0100
# Episode 4950/5000: Total Reward = 5.10, Steps = 98, Epsilon = 0.0100
# Episode 4951/5000: Total Reward = -0.60, Steps = 86, Epsilon = 0.0100
# Episode 4952/5000: Total Reward = 4.20, Steps = 86, Epsilon = 0.0100
# Episode 4953/5000: Total Reward = 0.90, Steps = 50, Epsilon = 0.0100
# Episode 4954/5000: Total Reward = -0.30, Steps = 50, Epsilon = 0.0100
# Episode 4955/5000: Total Reward = 1.20, Steps = 86, Epsilon = 0.0100
# Episode 4956/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4957/5000: Total Reward = 1.10, Steps = 46, Epsilon = 0.0100
# Episode 4958/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4959/5000: Total Reward = 0.00, Steps = 86, Epsilon = 0.0100
# Episode 4960/5000: Total Reward = 3.20, Steps = 136, Epsilon = 0.0100
# Episode 4961/5000: Total Reward = 4.50, Steps = 122, Epsilon = 0.0100
# Episode 4962/5000: Total Reward = 4.80, Steps = 68, Epsilon = 0.0100
# Episode 4963/5000: Total Reward = -9.30, Steps = 50, Epsilon = 0.0100
# Episode 4964/5000: Total Reward = -0.60, Steps = 62, Epsilon = 0.0100
# Episode 4965/5000: Total Reward = 2.00, Steps = 43, Epsilon = 0.0100
# Episode 4966/5000: Total Reward = -3.00, Steps = 86, Epsilon = 0.0100
# Episode 4967/5000: Total Reward = 0.30, Steps = 50, Epsilon = 0.0100
# Episode 4968/5000: Total Reward = 2.00, Steps = 43, Epsilon = 0.0100
# Episode 4969/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4970/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4971/5000: Total Reward = 1.80, Steps = 86, Epsilon = 0.0100
# Episode 4972/5000: Total Reward = -1.10, Steps = 63, Epsilon = 0.0100
# Episode 4973/5000: Total Reward = -3.20, Steps = 96, Epsilon = 0.0100
# Episode 4974/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4975/5000: Total Reward = -2.20, Steps = 55, Epsilon = 0.0100
# Episode 4976/5000: Total Reward = -2.20, Steps = 61, Epsilon = 0.0100
# Episode 4977/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4978/5000: Total Reward = 1.20, Steps = 86, Epsilon = 0.0100
# Episode 4979/5000: Total Reward = -0.00, Steps = 86, Epsilon = 0.0100
# Episode 4980/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4981/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4982/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4983/5000: Total Reward = -0.10, Steps = 97, Epsilon = 0.0100
# Episode 4984/5000: Total Reward = -0.60, Steps = 86, Epsilon = 0.0100
# Episode 4985/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4986/5000: Total Reward = 1.00, Steps = 66, Epsilon = 0.0100
# Episode 4987/5000: Total Reward = -0.30, Steps = 50, Epsilon = 0.0100
# Episode 4988/5000: Total Reward = -0.40, Steps = 70, Epsilon = 0.0100
# Episode 4989/5000: Total Reward = 3.70, Steps = 63, Epsilon = 0.0100
# Episode 4990/5000: Total Reward = 0.30, Steps = 50, Epsilon = 0.0100
# Episode 4991/5000: Total Reward = -0.40, Steps = 61, Epsilon = 0.0100
# Episode 4992/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4993/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4994/5000: Total Reward = -0.30, Steps = 50, Epsilon = 0.0100
# Episode 4995/5000: Total Reward = -9.30, Steps = 50, Epsilon = 0.0100
# Episode 4996/5000: Total Reward = -3.60, Steps = 86, Epsilon = 0.0100
# Episode 4997/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 4998/5000: Total Reward = 4.30, Steps = 63, Epsilon = 0.0100
# Episode 4999/5000: Total Reward = -0.90, Steps = 50, Epsilon = 0.0100
# Episode 5000/5000: Total Reward = -2.60, Steps = 57, Epsilon = 0.0100
# Checkpoint saved at episode 5000: flappy_bird_dqn_final_ep5000.pth
# Final model saved to flappy_bird_dqn_final.pth
# Training completed. Average Reward: 0.50, Average Steps: 61.84

# %%
# Load the trained model
model = load_model(env, "flappy_bird_dqn_final_ep4000.pth")

# Test the RL agent and create a flipped GIF
test_rl_agent_playing(env, model)
# Out:
# <ipython-input-7-b18a0f46fe67>:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# Step 0: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 1: Reward: 0.1, Done: False
# Step 1: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 2: Reward: 0.1, Done: False
# Step 2: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 3: Reward: 0.1, Done: False
# Step 3: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 4: Reward: 0.1, Done: False
# Step 4: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 5: Reward: 0.1, Done: False
# Step 5: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 6: Reward: 0.1, Done: False
# Step 6: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 7: Reward: 0.1, Done: False
# Step 7: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 8: Reward: 0.1, Done: False
# Step 8: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 9: Reward: 0.1, Done: False
# Step 9: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 10: Reward: 0.1, Done: False
# Step 10: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 11: Reward: 0.1, Done: False
# Step 11: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 12: Reward: 0.1, Done: False
# Step 12: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 13: Reward: 0.1, Done: False
# Step 13: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 14: Reward: 0.1, Done: False
# Step 14: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 15: Reward: 0.1, Done: False
# Step 15: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 16: Reward: 0.1, Done: False
# Step 16: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 17: Reward: 0.1, Done: False
# Step 17: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 18: Reward: 0.1, Done: False
# Step 18: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 19: Reward: 0.1, Done: False
# Step 19: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 20: Reward: 0.1, Done: False
# Step 20: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 21: Reward: 0.1, Done: False
# Step 21: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 22: Reward: 0.1, Done: False
# Step 22: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 23: Reward: 0.1, Done: False
# Step 23: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 24: Reward: 0.1, Done: False
# Step 24: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 25: Reward: 0.1, Done: False
# Step 25: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 26: Reward: 0.1, Done: False
# Step 26: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 27: Reward: 0.1, Done: False
# Step 27: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 28: Reward: 0.1, Done: False
# Step 28: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 29: Reward: 0.1, Done: False
# Step 29: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 30: Reward: 0.1, Done: False
# Step 30: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 31: Reward: 0.1, Done: False
# Step 31: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 32: Reward: 0.1, Done: False
# Step 32: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 33: Reward: 0.1, Done: False
# Step 33: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 34: Reward: 0.1, Done: False
# Step 34: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 35: Reward: 0.1, Done: False
# Step 35: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 36: Reward: 0.1, Done: False
# Step 36: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 37: Reward: 0.1, Done: False
# Step 37: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 38: Reward: 0.1, Done: False
# Step 38: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 39: Reward: 0.1, Done: False
# Step 39: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 40: Reward: 0.1, Done: False
# Step 40: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 41: Reward: 0.1, Done: False
# Step 41: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 42: Reward: -0.5, Done: False
# Step 42: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 43: Reward: 0.1, Done: False
# Step 43: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 44: Reward: 0.1, Done: False
# Step 44: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 45: Reward: 0.1, Done: False
# Step 45: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 46: Reward: 0.1, Done: False
# Step 46: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 47: Reward: 0.1, Done: False
# Step 47: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 48: Reward: 0.1, Done: False
# Step 48: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 49: Reward: 0.1, Done: False
# Step 49: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 50: Reward: 0.1, Done: False
# Step 50: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 51: Reward: 0.1, Done: False
# Step 51: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 52: Reward: -0.5, Done: False
# Step 52: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 53: Reward: -0.5, Done: False
# Step 53: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 54: Reward: -0.5, Done: False
# Step 54: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 55: Reward: -0.5, Done: False
# Step 55: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 56: Reward: -0.5, Done: False
# Step 56: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 57: Reward: -0.5, Done: False
# Step 57: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 58: Reward: -0.5, Done: False
# Step 58: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 59: Reward: -0.5, Done: False
# Step 59: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 60: Reward: -0.5, Done: False
# Step 60: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 61: Reward: 1, Done: False
# Step 61: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 62: Reward: 0.1, Done: False
# Step 62: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 63: Reward: 0.1, Done: False
# Step 63: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 64: Reward: 0.1, Done: False
# Step 64: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 65: Reward: 0.1, Done: False
# Step 65: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 66: Reward: 0.1, Done: False
# Step 66: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 67: Reward: 0.1, Done: False
# Step 67: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 68: Reward: 0.1, Done: False
# Step 68: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 69: Reward: 0.1, Done: False
# Step 69: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 70: Reward: 0.1, Done: False
# Step 70: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 71: Reward: 0.1, Done: False
# Step 71: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 72: Reward: 0.1, Done: False
# Step 72: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 73: Reward: 0.1, Done: False
# Step 73: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 74: Reward: 0.1, Done: False
# Step 74: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 75: Reward: 0.1, Done: False
# Step 75: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 76: Reward: 0.1, Done: False
# Step 76: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 77: Reward: 0.1, Done: False
# Step 77: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 78: Reward: 0.1, Done: False
# Step 78: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 79: Reward: 0.1, Done: False
# Step 79: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 80: Reward: 0.1, Done: False
# Step 80: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 81: Reward: 0.1, Done: False
# Step 81: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 82: Reward: -0.5, Done: False
# Step 82: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 83: Reward: -0.5, Done: False
# Step 83: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 84: Reward: -0.5, Done: False
# Step 84: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 85: Reward: -0.5, Done: False
# Step 85: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 86: Reward: 0.1, Done: False
# Step 86: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 87: Reward: 0.1, Done: False
# Step 87: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 88: Reward: 0.1, Done: False
# Step 88: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 89: Reward: 0.1, Done: False
# Step 89: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 90: Reward: 0.1, Done: False
# Step 90: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 91: Reward: 0.1, Done: False
# Step 91: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 92: Reward: 0.1, Done: False
# Step 92: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 93: Reward: 0.1, Done: False
# Step 93: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 94: Reward: 0.1, Done: False
# Step 94: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 95: Reward: 0.1, Done: False
# Step 95: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 96: Reward: 0.1, Done: False
# Step 96: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 97: Reward: 1, Done: False
# Step 97: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 98: Reward: 0.1, Done: False
# Step 98: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 99: Reward: 0.1, Done: False
# Step 99: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 100: Reward: 0.1, Done: False
# Step 100: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 101: Reward: 0.1, Done: False
# Step 101: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 102: Reward: 0.1, Done: False
# Step 102: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 103: Reward: 0.1, Done: False
# Step 103: State shape: (180,), State type: <class 'numpy.ndarray'>
# Step 104: Reward: -1, Done: True
